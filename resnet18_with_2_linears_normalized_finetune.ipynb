# %%
#lets try and use torch instead
from PIL import Image
import pathlib
import scipy.io
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import SGD
import torch.backends.cudnn as cudnn
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import time
import os
import copy
from torch.utils.data import DataLoader

# %%
NUM_CLASSES = 196

# %%
transforms = transforms.Compose(
[
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])
])
train = datasets.StanfordCars("cars", split="train", transform=transforms, download=True) #run these if its first time on REPO!
test = datasets.StanfordCars("cars", split="test", transform=transforms, download=True)

# train = datasets.StanfordCars("cars", split="train", transform=transforms)  #otherwise run these with the path to folder
# test = datasets.StanfordCars("cars", split="test", transform=transforms)
# Out:
# Downloading https://ai.stanford.edu/~jkrause/cars/car_devkit.tgz to cars/stanford_cars/car_devkit.tgz
#   0%|          | 0/330960 [00:00<?, ?it/s]
# Extracting cars/stanford_cars/car_devkit.tgz to cars/stanford_cars
# Downloading https://ai.stanford.edu/~jkrause/car196/cars_train.tgz to cars/stanford_cars/cars_train.tgz
#   0%|          | 0/979269282 [00:00<?, ?it/s]
# Extracting cars/stanford_cars/cars_train.tgz to cars/stanford_cars
# Using downloaded and verified file: cars/stanford_cars/car_devkit.tgz
# Extracting cars/stanford_cars/car_devkit.tgz to cars/stanford_cars
# Downloading https://ai.stanford.edu/~jkrause/car196/cars_test.tgz to cars/stanford_cars/cars_test.tgz
#   0%|          | 0/977350468 [00:00<?, ?it/s]
# Extracting cars/stanford_cars/cars_test.tgz to cars/stanford_cars
# Downloading https://ai.stanford.edu/~jkrause/car196/cars_test_annos_withlabels.mat to cars/stanford_cars/cars_test_annos_withlabels.mat
#   0%|          | 0/185758 [00:00<?, ?it/s]

# %%
train_loader = DataLoader(train, batch_size = 50, shuffle = True)
test_loader = DataLoader(test, batch_size = 50, shuffle = True)

# %%
resnet = models.resnet18(weights= "DEFAULT")
for param in resnet.parameters():
    param.requires_grad = False
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
#lets set the output layer to be our 196 classes
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
resnet.fc = nn.Sequential(nn.Linear(512, 1024), nn.ReLU(), nn.Dropout(p=0.2), nn.Linear(1024, NUM_CLASSES)) #lets add a multi layer network with 20% dropout for regularization
resnet.to(device)
optimizer = SGD(resnet.parameters(), lr=0.001, momentum=0.9)

#device = torch.device('cpu')
criterion = nn.CrossEntropyLoss()

# %%
print(device)
# Out:
# cuda:0

# %%
BATCH_SIZE = 50
EPOCHS = 50
print_every = 10
valid_loss_min = np.Inf
val_loss = []
val_acc = []
train_loss = []
train_acc = []
total_step = len(train_loader)

for epoch in range(1, EPOCHS+1):
    running_loss = 0.0
    correct = 0
    total=0
    print(f'Epoch {epoch}\n')
    for batch_idx, (data_, target_) in enumerate(train_loader):
        data_, target_ = data_.to(device), target_.to(device)
        optimizer.zero_grad()
        outputs = resnet(data_)
        loss = criterion(outputs, target_)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        _,pred = torch.max(outputs, dim=1)
        correct += torch.sum(pred==target_).item()
        total += target_.size(0)
        if (batch_idx) % 20 == 0:
            print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch, EPOCHS, batch_idx, total_step, loss.item()))
    train_acc.append(100 * correct / total)
    train_loss.append(running_loss/total_step)
    print(f'\ntrain-loss: {np.mean(train_loss):.4f}, train-acc: {(100 * correct/total):.4f}')
    batch_loss = 0
    total_t=0
    correct_t=0
    with torch.no_grad():
        resnet.eval()
        for data_t, target_t in (test_loader):
            data_t, target_t = data_t.to(device), target_t.to(device)
            outputs_t = resnet(data_t)
            loss_t = criterion(outputs_t, target_t)
            batch_loss += loss_t.item()
            _,pred_t = torch.max(outputs_t, dim=1)
            correct_t += torch.sum(pred_t==target_t).item()
            total_t += target_t.size(0)
        val_acc.append(100 * correct_t/total_t)
        val_loss.append(batch_loss/len(test_loader))
        network_learned = batch_loss < valid_loss_min
        print(f'validation loss: {np.mean(val_loss):.4f}, validation acc: {(100 * correct_t/total_t):.4f}\n')

        
        if network_learned:
            valid_loss_min = batch_loss
            torch.save(resnet.state_dict(), 'resnet.pt')
            print('Improvement-Detected, save-model')
    resnet.train()
# Out:
# Epoch 1
#
# Epoch [1/50], Step [0/163], Loss: 4.7423
# Epoch [1/50], Step [20/163], Loss: 4.6804
# Epoch [1/50], Step [40/163], Loss: 4.6164
# Epoch [1/50], Step [60/163], Loss: 4.6952
# Epoch [1/50], Step [80/163], Loss: 4.6090
# Epoch [1/50], Step [100/163], Loss: 4.6281
# Epoch [1/50], Step [120/163], Loss: 4.6201
# Epoch [1/50], Step [140/163], Loss: 4.6760
# Epoch [1/50], Step [160/163], Loss: 4.6418
#
# train-loss: 4.6522, train-acc: 10.7318
# validation loss: 4.6297, validation acc: 11.7523
#
# Improvement-Detected, save-model
# Epoch 2
#
# Epoch [2/50], Step [0/163], Loss: 4.5468
# Epoch [2/50], Step [20/163], Loss: 4.4492
# Epoch [2/50], Step [40/163], Loss: 4.5772
# Epoch [2/50], Step [60/163], Loss: 4.6775
# Epoch [2/50], Step [80/163], Loss: 4.3965
# Epoch [2/50], Step [100/163], Loss: 4.6413
# Epoch [2/50], Step [120/163], Loss: 4.5295
# Epoch [2/50], Step [140/163], Loss: 4.3983
# Epoch [2/50], Step [160/163], Loss: 4.5166
#
# train-loss: 4.5654, train-acc: 14.4155
# validation loss: 4.5498, validation acc: 13.3939
#
# Improvement-Detected, save-model
# Epoch 3
#
# Epoch [3/50], Step [0/163], Loss: 4.5455
# Epoch [3/50], Step [20/163], Loss: 4.3775
# Epoch [3/50], Step [40/163], Loss: 4.2699
# Epoch [3/50], Step [60/163], Loss: 4.3819
# Epoch [3/50], Step [80/163], Loss: 4.3604
# Epoch [3/50], Step [100/163], Loss: 4.3108
# Epoch [3/50], Step [120/163], Loss: 4.3141
# Epoch [3/50], Step [140/163], Loss: 4.3049
# Epoch [3/50], Step [160/163], Loss: 4.3443
#
# train-loss: 4.4819, train-acc: 16.1591
# validation loss: 4.4780, validation acc: 15.1225
#
# Improvement-Detected, save-model
# Epoch 4
#
# Epoch [4/50], Step [0/163], Loss: 4.2602
# Epoch [4/50], Step [20/163], Loss: 4.1826
# Epoch [4/50], Step [40/163], Loss: 4.1428
# Epoch [4/50], Step [60/163], Loss: 4.1705
# Epoch [4/50], Step [80/163], Loss: 4.0699
# Epoch [4/50], Step [100/163], Loss: 4.1376
# Epoch [4/50], Step [120/163], Loss: 4.0602
# Epoch [4/50], Step [140/163], Loss: 3.9843
# Epoch [4/50], Step [160/163], Loss: 4.0974
#
# train-loss: 4.3986, train-acc: 18.2711
# validation loss: 4.4068, validation acc: 17.1123
#
# Improvement-Detected, save-model
# Epoch 5
#
# Epoch [5/50], Step [0/163], Loss: 4.1463
# Epoch [5/50], Step [20/163], Loss: 4.1233
# Epoch [5/50], Step [40/163], Loss: 4.0722
# Epoch [5/50], Step [60/163], Loss: 4.0863
# Epoch [5/50], Step [80/163], Loss: 3.7031
# Epoch [5/50], Step [100/163], Loss: 3.9230
# Epoch [5/50], Step [120/163], Loss: 4.0490
# Epoch [5/50], Step [140/163], Loss: 3.6912
# Epoch [5/50], Step [160/163], Loss: 3.7851
#
# train-loss: 4.3173, train-acc: 21.3654
# validation loss: 4.3370, validation acc: 18.5052
#
# Improvement-Detected, save-model
# Epoch 6
#
# Epoch [6/50], Step [0/163], Loss: 4.0058
# Epoch [6/50], Step [20/163], Loss: 3.9035
# Epoch [6/50], Step [40/163], Loss: 3.9125
# Epoch [6/50], Step [60/163], Loss: 3.9497
# Epoch [6/50], Step [80/163], Loss: 3.9861
# Epoch [6/50], Step [100/163], Loss: 3.7149
# Epoch [6/50], Step [120/163], Loss: 3.6472
# Epoch [6/50], Step [140/163], Loss: 3.7286
# Epoch [6/50], Step [160/163], Loss: 3.8272
#
# train-loss: 4.2388, train-acc: 23.5511
# validation loss: 4.2706, validation acc: 18.6917
#
# Improvement-Detected, save-model
# Epoch 7
#
# Epoch [7/50], Step [0/163], Loss: 3.5884
# Epoch [7/50], Step [20/163], Loss: 3.3590
# Epoch [7/50], Step [40/163], Loss: 3.8090
# Epoch [7/50], Step [60/163], Loss: 3.6808
# Epoch [7/50], Step [80/163], Loss: 3.5767
# Epoch [7/50], Step [100/163], Loss: 3.5430
# Epoch [7/50], Step [120/163], Loss: 3.8244
# Epoch [7/50], Step [140/163], Loss: 3.9010
# Epoch [7/50], Step [160/163], Loss: 3.3707
#
# train-loss: 4.1628, train-acc: 25.3561
# validation loss: 4.2078, validation acc: 21.9500
#
# Improvement-Detected, save-model
# Epoch 8
#
# Epoch [8/50], Step [0/163], Loss: 3.6640
# Epoch [8/50], Step [20/163], Loss: 3.6284
# Epoch [8/50], Step [40/163], Loss: 3.4664
# Epoch [8/50], Step [60/163], Loss: 3.3902
# Epoch [8/50], Step [80/163], Loss: 3.6032
# Epoch [8/50], Step [100/163], Loss: 3.6463
# Epoch [8/50], Step [120/163], Loss: 3.4906
# Epoch [8/50], Step [140/163], Loss: 3.6684
# Epoch [8/50], Step [160/163], Loss: 3.6565
#
# train-loss: 4.0889, train-acc: 27.2471
# validation loss: 4.1481, validation acc: 22.6713
#
# Improvement-Detected, save-model
# Epoch 9
#
# Epoch [9/50], Step [0/163], Loss: 3.4710
# Epoch [9/50], Step [20/163], Loss: 3.5662
# Epoch [9/50], Step [40/163], Loss: 3.3830
# Epoch [9/50], Step [60/163], Loss: 3.4674
# Epoch [9/50], Step [80/163], Loss: 3.5451
# Epoch [9/50], Step [100/163], Loss: 3.3780
# Epoch [9/50], Step [120/163], Loss: 3.3495
# Epoch [9/50], Step [140/163], Loss: 3.4882
# Epoch [9/50], Step [160/163], Loss: 3.5564
#
# train-loss: 4.0180, train-acc: 29.2117
# validation loss: 4.0907, validation acc: 23.7284
#
# Improvement-Detected, save-model
# Epoch 10
#
# Epoch [10/50], Step [0/163], Loss: 3.4084
# Epoch [10/50], Step [20/163], Loss: 3.7087
# Epoch [10/50], Step [40/163], Loss: 3.3733
# Epoch [10/50], Step [60/163], Loss: 3.4931
# Epoch [10/50], Step [80/163], Loss: 3.3170
# Epoch [10/50], Step [100/163], Loss: 3.3232
# Epoch [10/50], Step [120/163], Loss: 3.1388
# Epoch [10/50], Step [140/163], Loss: 2.9885
# Epoch [10/50], Step [160/163], Loss: 3.6911
#
# train-loss: 3.9506, train-acc: 30.8694
# validation loss: 4.0368, validation acc: 23.9149
#
# Improvement-Detected, save-model
# Epoch 11
#
# Epoch [11/50], Step [0/163], Loss: 3.2067
# Epoch [11/50], Step [20/163], Loss: 3.2457
# Epoch [11/50], Step [40/163], Loss: 3.0949
# Epoch [11/50], Step [60/163], Loss: 3.1097
# Epoch [11/50], Step [80/163], Loss: 3.2796
# Epoch [11/50], Step [100/163], Loss: 3.2733
# Epoch [11/50], Step [120/163], Loss: 3.2310
# Epoch [11/50], Step [140/163], Loss: 3.0504
# Epoch [11/50], Step [160/163], Loss: 3.2746
#
# train-loss: 3.8847, train-acc: 32.8463
# validation loss: 3.9849, validation acc: 25.6560
#
# Improvement-Detected, save-model
# Epoch 12
#
# Epoch [12/50], Step [0/163], Loss: 2.9174
# Epoch [12/50], Step [20/163], Loss: 3.0651
# Epoch [12/50], Step [40/163], Loss: 3.4176
# Epoch [12/50], Step [60/163], Loss: 3.0062
# Epoch [12/50], Step [80/163], Loss: 3.3663
# Epoch [12/50], Step [100/163], Loss: 2.9636
# Epoch [12/50], Step [120/163], Loss: 3.0346
# Epoch [12/50], Step [140/163], Loss: 3.2577
# Epoch [12/50], Step [160/163], Loss: 3.0279
#
# train-loss: 3.8222, train-acc: 33.9145
# validation loss: 3.9364, validation acc: 26.3773
#
# Improvement-Detected, save-model
# Epoch 13
#
# Epoch [13/50], Step [0/163], Loss: 2.8897
# Epoch [13/50], Step [20/163], Loss: 3.0872
# Epoch [13/50], Step [40/163], Loss: 2.9684
# Epoch [13/50], Step [60/163], Loss: 2.8697
# Epoch [13/50], Step [80/163], Loss: 3.0817
# Epoch [13/50], Step [100/163], Loss: 2.7916
# Epoch [13/50], Step [120/163], Loss: 3.1526
# Epoch [13/50], Step [140/163], Loss: 2.9200
# Epoch [13/50], Step [160/163], Loss: 3.2560
#
# train-loss: 3.7624, train-acc: 35.4003
# validation loss: 3.8904, validation acc: 26.8375
#
# Improvement-Detected, save-model
# Epoch 14
#
# Epoch [14/50], Step [0/163], Loss: 2.9247
# Epoch [14/50], Step [20/163], Loss: 3.2396
# Epoch [14/50], Step [40/163], Loss: 2.9137
# Epoch [14/50], Step [60/163], Loss: 2.9211
# Epoch [14/50], Step [80/163], Loss: 3.1526
# Epoch [14/50], Step [100/163], Loss: 2.6785
# Epoch [14/50], Step [120/163], Loss: 2.9236
# Epoch [14/50], Step [140/163], Loss: 2.9174
# Epoch [14/50], Step [160/163], Loss: 2.7814
#
# train-loss: 3.7048, train-acc: 36.8983
# validation loss: 3.8466, validation acc: 26.8872
#
# Improvement-Detected, save-model
# Epoch 15
#
# Epoch [15/50], Step [0/163], Loss: 2.7798
# Epoch [15/50], Step [20/163], Loss: 3.1607
# Epoch [15/50], Step [40/163], Loss: 2.9447
# Epoch [15/50], Step [60/163], Loss: 3.1089
# Epoch [15/50], Step [80/163], Loss: 2.7081
# Epoch [15/50], Step [100/163], Loss: 2.6594
# Epoch [15/50], Step [120/163], Loss: 2.8453
# Epoch [15/50], Step [140/163], Loss: 2.6823
# Epoch [15/50], Step [160/163], Loss: 2.9493
#
# train-loss: 3.6486, train-acc: 38.3964
# validation loss: 3.8047, validation acc: 27.9692
#
# Improvement-Detected, save-model
# Epoch 16
#
# Epoch [16/50], Step [0/163], Loss: 2.8088
# Epoch [16/50], Step [20/163], Loss: 2.9674
# Epoch [16/50], Step [40/163], Loss: 3.1738
# Epoch [16/50], Step [60/163], Loss: 2.9220
# Epoch [16/50], Step [80/163], Loss: 2.8033
# Epoch [16/50], Step [100/163], Loss: 3.1324
# Epoch [16/50], Step [120/163], Loss: 2.4874
# Epoch [16/50], Step [140/163], Loss: 3.2154
# Epoch [16/50], Step [160/163], Loss: 2.8497
#
# train-loss: 3.5948, train-acc: 39.9681
# validation loss: 3.7648, validation acc: 28.0811
#
# Improvement-Detected, save-model
# Epoch 17
#
# Epoch [17/50], Step [0/163], Loss: 2.6707
# Epoch [17/50], Step [20/163], Loss: 2.5982
# Epoch [17/50], Step [40/163], Loss: 2.6907
# Epoch [17/50], Step [60/163], Loss: 2.8902
# Epoch [17/50], Step [80/163], Loss: 2.8060
# Epoch [17/50], Step [100/163], Loss: 2.6293
# Epoch [17/50], Step [120/163], Loss: 2.6377
# Epoch [17/50], Step [140/163], Loss: 2.7059
# Epoch [17/50], Step [160/163], Loss: 2.9353
#
# train-loss: 3.5437, train-acc: 40.2014
# validation loss: 3.7266, validation acc: 29.1879
#
# Improvement-Detected, save-model
# Epoch 18
#
# Epoch [18/50], Step [0/163], Loss: 2.5463
# Epoch [18/50], Step [20/163], Loss: 2.8224
# Epoch [18/50], Step [40/163], Loss: 2.7765
# Epoch [18/50], Step [60/163], Loss: 2.5672
# Epoch [18/50], Step [80/163], Loss: 2.3852
# Epoch [18/50], Step [100/163], Loss: 2.4935
# Epoch [18/50], Step [120/163], Loss: 2.8110
# Epoch [18/50], Step [140/163], Loss: 2.3626
# Epoch [18/50], Step [160/163], Loss: 2.5626
#
# train-loss: 3.4945, train-acc: 41.6012
# validation loss: 3.6900, validation acc: 29.9963
#
# Improvement-Detected, save-model
# Epoch 19
#
# Epoch [19/50], Step [0/163], Loss: 2.6165
# Epoch [19/50], Step [20/163], Loss: 2.4184
# Epoch [19/50], Step [40/163], Loss: 2.5287
# Epoch [19/50], Step [60/163], Loss: 2.9933
# Epoch [19/50], Step [80/163], Loss: 2.7927
# Epoch [19/50], Step [100/163], Loss: 2.6072
# Epoch [19/50], Step [120/163], Loss: 2.1474
# Epoch [19/50], Step [140/163], Loss: 2.1311
# Epoch [19/50], Step [160/163], Loss: 2.4832
#
# train-loss: 3.4466, train-acc: 43.3325
# validation loss: 3.6547, validation acc: 30.7549
#
# Improvement-Detected, save-model
# Epoch 20
#
# Epoch [20/50], Step [0/163], Loss: 2.5509
# Epoch [20/50], Step [20/163], Loss: 2.4920
# Epoch [20/50], Step [40/163], Loss: 2.3625
# Epoch [20/50], Step [60/163], Loss: 2.5962
# Epoch [20/50], Step [80/163], Loss: 2.1695
# Epoch [20/50], Step [100/163], Loss: 2.7889
# Epoch [20/50], Step [120/163], Loss: 2.4790
# Epoch [20/50], Step [140/163], Loss: 2.5631
# Epoch [20/50], Step [160/163], Loss: 2.6936
#
# train-loss: 3.4006, train-acc: 44.0938
# validation loss: 3.6212, validation acc: 31.0409
#
# Improvement-Detected, save-model
# Epoch 21
#
# Epoch [21/50], Step [0/163], Loss: 2.3248
# Epoch [21/50], Step [20/163], Loss: 2.2585
# Epoch [21/50], Step [40/163], Loss: 2.3084
# Epoch [21/50], Step [60/163], Loss: 2.4423
# Epoch [21/50], Step [80/163], Loss: 2.3069
# Epoch [21/50], Step [100/163], Loss: 2.6149
# Epoch [21/50], Step [120/163], Loss: 2.5745
# Epoch [21/50], Step [140/163], Loss: 2.4168
# Epoch [21/50], Step [160/163], Loss: 2.2985
#
# train-loss: 3.3558, train-acc: 45.3831
# validation loss: 3.5896, validation acc: 31.5135
#
# Improvement-Detected, save-model
# Epoch 22
#
# Epoch [22/50], Step [0/163], Loss: 2.2997
# Epoch [22/50], Step [20/163], Loss: 2.2424
# Epoch [22/50], Step [40/163], Loss: 2.6537
# Epoch [22/50], Step [60/163], Loss: 2.3766
# Epoch [22/50], Step [80/163], Loss: 2.3974
# Epoch [22/50], Step [100/163], Loss: 2.4155
# Epoch [22/50], Step [120/163], Loss: 2.2013
# Epoch [22/50], Step [140/163], Loss: 2.2077
# Epoch [22/50], Step [160/163], Loss: 2.3008
#
# train-loss: 3.3129, train-acc: 46.1935
# validation loss: 3.5590, validation acc: 32.2472
#
# Improvement-Detected, save-model
# Epoch 23
#
# Epoch [23/50], Step [0/163], Loss: 2.2035
# Epoch [23/50], Step [20/163], Loss: 2.4096
# Epoch [23/50], Step [40/163], Loss: 2.4590
# Epoch [23/50], Step [60/163], Loss: 2.5647
# Epoch [23/50], Step [80/163], Loss: 2.1753
# Epoch [23/50], Step [100/163], Loss: 2.1677
# Epoch [23/50], Step [120/163], Loss: 2.3571
# Epoch [23/50], Step [140/163], Loss: 2.5318
# Epoch [23/50], Step [160/163], Loss: 2.5963
#
# train-loss: 3.2715, train-acc: 47.2495
# validation loss: 3.5299, validation acc: 32.5581
#
# Improvement-Detected, save-model
# Epoch 24
#
# Epoch [24/50], Step [0/163], Loss: 2.4307
# Epoch [24/50], Step [20/163], Loss: 2.6007
# Epoch [24/50], Step [40/163], Loss: 2.0221
# Epoch [24/50], Step [60/163], Loss: 2.3463
# Epoch [24/50], Step [80/163], Loss: 2.3302
# Epoch [24/50], Step [100/163], Loss: 2.4484
# Epoch [24/50], Step [120/163], Loss: 2.5115
# Epoch [24/50], Step [140/163], Loss: 2.1227
# Epoch [24/50], Step [160/163], Loss: 2.1512
#
# train-loss: 3.2313, train-acc: 48.5388
# validation loss: 3.5022, validation acc: 32.9561
#
# Improvement-Detected, save-model
# Epoch 25
#
# Epoch [25/50], Step [0/163], Loss: 2.3468
# Epoch [25/50], Step [20/163], Loss: 2.2913
# Epoch [25/50], Step [40/163], Loss: 2.0672
# Epoch [25/50], Step [60/163], Loss: 2.5402
# Epoch [25/50], Step [80/163], Loss: 2.4894
# Epoch [25/50], Step [100/163], Loss: 1.9504
# Epoch [25/50], Step [120/163], Loss: 2.3544
# Epoch [25/50], Step [140/163], Loss: 2.2337
# Epoch [25/50], Step [160/163], Loss: 2.1018
#
# train-loss: 3.1920, train-acc: 49.6562
# validation loss: 3.4756, validation acc: 32.8442
#
# Improvement-Detected, save-model
# Epoch 26
#
# Epoch [26/50], Step [0/163], Loss: 2.3170
# Epoch [26/50], Step [20/163], Loss: 2.0441
# Epoch [26/50], Step [40/163], Loss: 2.1068
# Epoch [26/50], Step [60/163], Loss: 2.6330
# Epoch [26/50], Step [80/163], Loss: 1.8245
# Epoch [26/50], Step [100/163], Loss: 2.2381
# Epoch [26/50], Step [120/163], Loss: 2.1923
# Epoch [26/50], Step [140/163], Loss: 1.8292
# Epoch [26/50], Step [160/163], Loss: 2.2872
#
# train-loss: 3.1542, train-acc: 49.8527
# validation loss: 3.4495, validation acc: 34.3241
#
# Improvement-Detected, save-model
# Epoch 27
#
# Epoch [27/50], Step [0/163], Loss: 2.0748
# Epoch [27/50], Step [20/163], Loss: 2.1009
# Epoch [27/50], Step [40/163], Loss: 2.2518
# Epoch [27/50], Step [60/163], Loss: 2.1136
# Epoch [27/50], Step [80/163], Loss: 2.4227
# Epoch [27/50], Step [100/163], Loss: 2.0662
# Epoch [27/50], Step [120/163], Loss: 2.3790
# Epoch [27/50], Step [140/163], Loss: 2.2938
# Epoch [27/50], Step [160/163], Loss: 2.1329
#
# train-loss: 3.1177, train-acc: 50.7981
# validation loss: 3.4247, validation acc: 34.0878
#
# Improvement-Detected, save-model
# Epoch 28
#
# Epoch [28/50], Step [0/163], Loss: 2.1497
# Epoch [28/50], Step [20/163], Loss: 2.5794
# Epoch [28/50], Step [40/163], Loss: 2.0817
# Epoch [28/50], Step [60/163], Loss: 2.0482
# Epoch [28/50], Step [80/163], Loss: 2.5154
# Epoch [28/50], Step [100/163], Loss: 1.9675
# Epoch [28/50], Step [120/163], Loss: 2.2290
# Epoch [28/50], Step [140/163], Loss: 2.2006
# Epoch [28/50], Step [160/163], Loss: 2.0664
#
# train-loss: 3.0825, train-acc: 51.9769
# validation loss: 3.4008, validation acc: 34.9210
#
# Improvement-Detected, save-model
# Epoch 29
#
# Epoch [29/50], Step [0/163], Loss: 2.1802
# Epoch [29/50], Step [20/163], Loss: 1.9032
# Epoch [29/50], Step [40/163], Loss: 2.4168
# Epoch [29/50], Step [60/163], Loss: 2.0938
# Epoch [29/50], Step [80/163], Loss: 2.0350
# Epoch [29/50], Step [100/163], Loss: 1.8712
# Epoch [29/50], Step [120/163], Loss: 2.2410
# Epoch [29/50], Step [140/163], Loss: 2.1312
# Epoch [29/50], Step [160/163], Loss: 1.7200
#
# train-loss: 3.0483, train-acc: 53.3030
# validation loss: 3.3779, validation acc: 34.5106
#
# Improvement-Detected, save-model
# Epoch 30
#
# Epoch [30/50], Step [0/163], Loss: 1.9610
# Epoch [30/50], Step [20/163], Loss: 2.0208
# Epoch [30/50], Step [40/163], Loss: 1.9954
# Epoch [30/50], Step [60/163], Loss: 2.2171
# Epoch [30/50], Step [80/163], Loss: 1.8518
# Epoch [30/50], Step [100/163], Loss: 1.9637
# Epoch [30/50], Step [120/163], Loss: 1.9426
# Epoch [30/50], Step [140/163], Loss: 2.2408
# Epoch [30/50], Step [160/163], Loss: 2.2873
#
# train-loss: 3.0150, train-acc: 53.0329
# validation loss: 3.3557, validation acc: 35.2941
#
# Improvement-Detected, save-model
# Epoch 31
#
# Epoch [31/50], Step [0/163], Loss: 2.0498
# Epoch [31/50], Step [20/163], Loss: 2.1810
# Epoch [31/50], Step [40/163], Loss: 2.0017
# Epoch [31/50], Step [60/163], Loss: 1.9852
# Epoch [31/50], Step [80/163], Loss: 2.3749
# Epoch [31/50], Step [100/163], Loss: 2.4671
# Epoch [31/50], Step [120/163], Loss: 1.9589
# Epoch [31/50], Step [140/163], Loss: 2.2443
# Epoch [31/50], Step [160/163], Loss: 1.8029
#
# train-loss: 2.9820, train-acc: 54.9239
# validation loss: 3.3343, validation acc: 35.3439
#
# Improvement-Detected, save-model
# Epoch 32
#
# Epoch [32/50], Step [0/163], Loss: 1.9098
# Epoch [32/50], Step [20/163], Loss: 1.9754
# Epoch [32/50], Step [40/163], Loss: 2.0429
# Epoch [32/50], Step [60/163], Loss: 1.6628
# Epoch [32/50], Step [80/163], Loss: 2.1174
# Epoch [32/50], Step [100/163], Loss: 2.1547
# Epoch [32/50], Step [120/163], Loss: 2.0355
# Epoch [32/50], Step [140/163], Loss: 1.8056
# Epoch [32/50], Step [160/163], Loss: 1.9932
#
# train-loss: 2.9502, train-acc: 54.6415
# validation loss: 3.3138, validation acc: 35.3936
#
# Improvement-Detected, save-model
# Epoch 33
#
# Epoch [33/50], Step [0/163], Loss: 1.8692
# Epoch [33/50], Step [20/163], Loss: 1.9522
# Epoch [33/50], Step [40/163], Loss: 1.9923
# Epoch [33/50], Step [60/163], Loss: 1.4966
# Epoch [33/50], Step [80/163], Loss: 1.8565
# Epoch [33/50], Step [100/163], Loss: 2.0349
# Epoch [33/50], Step [120/163], Loss: 1.7177
# Epoch [33/50], Step [140/163], Loss: 1.8018
# Epoch [33/50], Step [160/163], Loss: 1.9420
#
# train-loss: 2.9191, train-acc: 56.2991
# validation loss: 3.2941, validation acc: 35.8537
#
# Improvement-Detected, save-model
# Epoch 34
#
# Epoch [34/50], Step [0/163], Loss: 1.6449
# Epoch [34/50], Step [20/163], Loss: 2.1162
# Epoch [34/50], Step [40/163], Loss: 1.8948
# Epoch [34/50], Step [60/163], Loss: 1.8145
# Epoch [34/50], Step [80/163], Loss: 1.9017
# Epoch [34/50], Step [100/163], Loss: 1.7452
# Epoch [34/50], Step [120/163], Loss: 1.6827
# Epoch [34/50], Step [140/163], Loss: 1.7113
# Epoch [34/50], Step [160/163], Loss: 1.8764
#
# train-loss: 2.8892, train-acc: 56.0658
# validation loss: 3.2752, validation acc: 35.9035
#
# Improvement-Detected, save-model
# Epoch 35
#
# Epoch [35/50], Step [0/163], Loss: 1.9444
# Epoch [35/50], Step [20/163], Loss: 1.8072
# Epoch [35/50], Step [40/163], Loss: 1.9365
# Epoch [35/50], Step [60/163], Loss: 2.1665
# Epoch [35/50], Step [80/163], Loss: 2.0539
# Epoch [35/50], Step [100/163], Loss: 1.7764
# Epoch [35/50], Step [120/163], Loss: 2.0119
# Epoch [35/50], Step [140/163], Loss: 2.0657
# Epoch [35/50], Step [160/163], Loss: 1.9764
#
# train-loss: 2.8600, train-acc: 57.4902
# validation loss: 3.2567, validation acc: 36.5377
#
# Improvement-Detected, save-model
# Epoch 36
#
# Epoch [36/50], Step [0/163], Loss: 1.9909
# Epoch [36/50], Step [20/163], Loss: 1.9987
# Epoch [36/50], Step [40/163], Loss: 1.8653
# Epoch [36/50], Step [60/163], Loss: 2.0911
# Epoch [36/50], Step [80/163], Loss: 2.2213
# Epoch [36/50], Step [100/163], Loss: 1.9084
# Epoch [36/50], Step [120/163], Loss: 1.4802
# Epoch [36/50], Step [140/163], Loss: 1.9354
# Epoch [36/50], Step [160/163], Loss: 1.9014
#
# train-loss: 2.8317, train-acc: 57.5884
# validation loss: 3.2386, validation acc: 37.1347
#
# Improvement-Detected, save-model
# Epoch 37
#
# Epoch [37/50], Step [0/163], Loss: 1.7998
# Epoch [37/50], Step [20/163], Loss: 1.6557
# Epoch [37/50], Step [40/163], Loss: 1.7557
# Epoch [37/50], Step [60/163], Loss: 1.8015
# Epoch [37/50], Step [80/163], Loss: 1.9641
# Epoch [37/50], Step [100/163], Loss: 1.8966
# Epoch [37/50], Step [120/163], Loss: 1.6279
# Epoch [37/50], Step [140/163], Loss: 1.9302
# Epoch [37/50], Step [160/163], Loss: 1.9147
#
# train-loss: 2.8037, train-acc: 58.6444
# validation loss: 3.2213, validation acc: 37.6943
#
# Improvement-Detected, save-model
# Epoch 38
#
# Epoch [38/50], Step [0/163], Loss: 1.7616
# Epoch [38/50], Step [20/163], Loss: 1.5268
# Epoch [38/50], Step [40/163], Loss: 1.7207
# Epoch [38/50], Step [60/163], Loss: 1.7161
# Epoch [38/50], Step [80/163], Loss: 2.1284
# Epoch [38/50], Step [100/163], Loss: 1.8072
# Epoch [38/50], Step [120/163], Loss: 1.6937
# Epoch [38/50], Step [140/163], Loss: 1.7213
# Epoch [38/50], Step [160/163], Loss: 1.8724
#
# train-loss: 2.7765, train-acc: 59.3934
# validation loss: 3.2045, validation acc: 37.3337
#
# Improvement-Detected, save-model
# Epoch 39
#
# Epoch [39/50], Step [0/163], Loss: 1.8091
# Epoch [39/50], Step [20/163], Loss: 2.0433
# Epoch [39/50], Step [40/163], Loss: 2.0350
# Epoch [39/50], Step [60/163], Loss: 1.4968
# Epoch [39/50], Step [80/163], Loss: 1.6113
# Epoch [39/50], Step [100/163], Loss: 1.8230
# Epoch [39/50], Step [120/163], Loss: 1.6692
# Epoch [39/50], Step [140/163], Loss: 1.5857
# Epoch [39/50], Step [160/163], Loss: 1.4863
#
# train-loss: 2.7501, train-acc: 59.8232
# validation loss: 3.1881, validation acc: 37.6321
#
# Improvement-Detected, save-model
# Epoch 40
#
# Epoch [40/50], Step [0/163], Loss: 1.4089
# Epoch [40/50], Step [20/163], Loss: 1.5945
# Epoch [40/50], Step [40/163], Loss: 1.4535
# Epoch [40/50], Step [60/163], Loss: 1.4097
# Epoch [40/50], Step [80/163], Loss: 1.6270
# Epoch [40/50], Step [100/163], Loss: 1.8329
# Epoch [40/50], Step [120/163], Loss: 1.6545
# Epoch [40/50], Step [140/163], Loss: 1.4549
# Epoch [40/50], Step [160/163], Loss: 1.7220
#
# train-loss: 2.7243, train-acc: 60.0442
# validation loss: 3.1723, validation acc: 37.8187
#
# Improvement-Detected, save-model
# Epoch 41
#
# Epoch [41/50], Step [0/163], Loss: 1.9037
# Epoch [41/50], Step [20/163], Loss: 1.7603
# Epoch [41/50], Step [40/163], Loss: 1.9238
# Epoch [41/50], Step [60/163], Loss: 1.7575
# Epoch [41/50], Step [80/163], Loss: 1.5638
# Epoch [41/50], Step [100/163], Loss: 1.6199
# Epoch [41/50], Step [120/163], Loss: 1.5406
# Epoch [41/50], Step [140/163], Loss: 1.8469
# Epoch [41/50], Step [160/163], Loss: 1.5972
#
# train-loss: 2.6990, train-acc: 61.4072
# validation loss: 3.1569, validation acc: 38.0798
#
# Improvement-Detected, save-model
# Epoch 42
#
# Epoch [42/50], Step [0/163], Loss: 1.6851
# Epoch [42/50], Step [20/163], Loss: 1.4783
# Epoch [42/50], Step [40/163], Loss: 1.5283
# Epoch [42/50], Step [60/163], Loss: 1.9024
# Epoch [42/50], Step [80/163], Loss: 1.6066
# Epoch [42/50], Step [100/163], Loss: 1.8162
# Epoch [42/50], Step [120/163], Loss: 1.8251
# Epoch [42/50], Step [140/163], Loss: 1.4073
# Epoch [42/50], Step [160/163], Loss: 1.3445
#
# train-loss: 2.6739, train-acc: 61.3458
# validation loss: 3.1424, validation acc: 37.5202
#
# Epoch 43
#
# Epoch [43/50], Step [0/163], Loss: 1.3877
# Epoch [43/50], Step [20/163], Loss: 1.6685
# Epoch [43/50], Step [40/163], Loss: 1.5652
# Epoch [43/50], Step [60/163], Loss: 1.4052
# Epoch [43/50], Step [80/163], Loss: 1.4734
# Epoch [43/50], Step [100/163], Loss: 1.6300
# Epoch [43/50], Step [120/163], Loss: 1.3553
# Epoch [43/50], Step [140/163], Loss: 1.5661
# Epoch [43/50], Step [160/163], Loss: 1.4520
#
# train-loss: 2.6495, train-acc: 62.1930
# validation loss: 3.1281, validation acc: 37.9555
#
# Improvement-Detected, save-model
# Epoch 44
#
# Epoch [44/50], Step [0/163], Loss: 1.7132
# Epoch [44/50], Step [20/163], Loss: 1.2745
# Epoch [44/50], Step [40/163], Loss: 1.8406
# Epoch [44/50], Step [60/163], Loss: 1.9639
# Epoch [44/50], Step [80/163], Loss: 1.3949
# Epoch [44/50], Step [100/163], Loss: 1.3515
# Epoch [44/50], Step [120/163], Loss: 1.2062
# Epoch [44/50], Step [140/163], Loss: 1.3048
# Epoch [44/50], Step [160/163], Loss: 1.6390
#
# train-loss: 2.6257, train-acc: 62.7701
# validation loss: 3.1142, validation acc: 38.3783
#
# Improvement-Detected, save-model
# Epoch 45
#
# Epoch [45/50], Step [0/163], Loss: 1.5912
# Epoch [45/50], Step [20/163], Loss: 1.5070
# Epoch [45/50], Step [40/163], Loss: 1.4943
# Epoch [45/50], Step [60/163], Loss: 1.6389
# Epoch [45/50], Step [80/163], Loss: 1.8294
# Epoch [45/50], Step [100/163], Loss: 1.3415
# Epoch [45/50], Step [120/163], Loss: 1.7946
# Epoch [45/50], Step [140/163], Loss: 1.3430
# Epoch [45/50], Step [160/163], Loss: 1.5068
#
# train-loss: 2.6024, train-acc: 63.2859
# validation loss: 3.1009, validation acc: 38.5400
#
# Improvement-Detected, save-model
# Epoch 46
#
# Epoch [46/50], Step [0/163], Loss: 1.6634
# Epoch [46/50], Step [20/163], Loss: 1.4027
# Epoch [46/50], Step [40/163], Loss: 1.5324
# Epoch [46/50], Step [60/163], Loss: 1.4642
# Epoch [46/50], Step [80/163], Loss: 1.9473
# Epoch [46/50], Step [100/163], Loss: 1.6392
# Epoch [46/50], Step [120/163], Loss: 1.6613
# Epoch [46/50], Step [140/163], Loss: 1.4640
# Epoch [46/50], Step [160/163], Loss: 1.5440
#
# train-loss: 2.5798, train-acc: 62.8929
# validation loss: 3.0879, validation acc: 38.4281
#
# Improvement-Detected, save-model
# Epoch 47
#
# Epoch [47/50], Step [0/163], Loss: 1.3285
# Epoch [47/50], Step [20/163], Loss: 1.4607
# Epoch [47/50], Step [40/163], Loss: 1.5703
# Epoch [47/50], Step [60/163], Loss: 1.4670
# Epoch [47/50], Step [80/163], Loss: 1.5735
# Epoch [47/50], Step [100/163], Loss: 1.2656
# Epoch [47/50], Step [120/163], Loss: 1.5134
# Epoch [47/50], Step [140/163], Loss: 1.6150
# Epoch [47/50], Step [160/163], Loss: 1.7698
#
# train-loss: 2.5576, train-acc: 64.0963
# validation loss: 3.0753, validation acc: 38.3410
#
# Improvement-Detected, save-model
# Epoch 48
#
# Epoch [48/50], Step [0/163], Loss: 1.2535
# Epoch [48/50], Step [20/163], Loss: 1.4337
# Epoch [48/50], Step [40/163], Loss: 2.0060
# Epoch [48/50], Step [60/163], Loss: 1.5932
# Epoch [48/50], Step [80/163], Loss: 1.3354
# Epoch [48/50], Step [100/163], Loss: 1.5714
# Epoch [48/50], Step [120/163], Loss: 1.5821
# Epoch [48/50], Step [140/163], Loss: 1.4239
# Epoch [48/50], Step [160/163], Loss: 1.9636
#
# train-loss: 2.5360, train-acc: 64.5751
# validation loss: 3.0633, validation acc: 38.4156
#
# Improvement-Detected, save-model
# Epoch 49
#
# Epoch [49/50], Step [0/163], Loss: 1.7056
# Epoch [49/50], Step [20/163], Loss: 1.6822
# Epoch [49/50], Step [40/163], Loss: 1.4477
# Epoch [49/50], Step [60/163], Loss: 1.3052
# Epoch [49/50], Step [80/163], Loss: 1.4625
# Epoch [49/50], Step [100/163], Loss: 1.3704
# Epoch [49/50], Step [120/163], Loss: 1.2716
# Epoch [49/50], Step [140/163], Loss: 1.6706
# Epoch [49/50], Step [160/163], Loss: 1.4551
#
# train-loss: 2.5145, train-acc: 65.2137
# validation loss: 3.0515, validation acc: 38.6270
#
# Improvement-Detected, save-model
# Epoch 50
#
# Epoch [50/50], Step [0/163], Loss: 1.3795
# Epoch [50/50], Step [20/163], Loss: 1.5290
# Epoch [50/50], Step [40/163], Loss: 1.4236
# Epoch [50/50], Step [60/163], Loss: 1.2468
# Epoch [50/50], Step [80/163], Loss: 1.3046
# Epoch [50/50], Step [100/163], Loss: 1.4479
# Epoch [50/50], Step [120/163], Loss: 1.4722
# Epoch [50/50], Step [140/163], Loss: 1.0806
# Epoch [50/50], Step [160/163], Loss: 1.4821
#
# train-loss: 2.4936, train-acc: 65.5697
# validation loss: 3.0401, validation acc: 38.6892
#
# Improvement-Detected, save-model

# %% [markdown]
# Here we see an improvment in our best validation accuracy up to around 40%, again considering this is a relatively small pretrained model (Resnet18) getting 40% accuracy means the model is likly picking up large scale differences between makes of different manufacturers, which is better than I expected from such a simple model + classification head.
